# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "./Source Data/nation.1751_2014.csv"
csv_file2 = "./Source Data/countries_geo.csv"
climate_df = pd.read_csv(csv_file)
countries_df = pd.read_csv(csv_file2)
climate_df.head()
# Out:
#                                               Nation    Year  \
# 0              (Note: missing values denoted by ".")     NaN
# 1  Source: Tom Boden and Bob Andres (Oak Ridge Na...     NaN
# 2                     DOI: 10.3334/CDIAC/00001_V2017     NaN
# 3                                        AFGHANISTAN  1949.0
# 4                                        AFGHANISTAN  1950.0
#
#    Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                4.0
# 4                                               23.0
#
#   Emissions from solid fuel consumption  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                     4
# ...

# %%
climate_clean_df = climate_df.dropna()
climate_clean_df.head()
# Out:
#         Nation    Year  \
# 3  AFGHANISTAN  1949.0
# 4  AFGHANISTAN  1950.0
# 5  AFGHANISTAN  1951.0
# 6  AFGHANISTAN  1952.0
# 7  AFGHANISTAN  1953.0
#
#    Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 3                                                4.0
# 4                                               23.0
# 5                                               25.0
# 6                                               25.0
# 7                                               29.0
#
#   Emissions from solid fuel consumption  \
# 3                                     4
# 4                                     6
# 5                                     7
# 6                                     9
# 7                                    10
#
#   Emissions from liquid fuel consumption Emissions from gas fuel consumption  \
# 3                                      0                                   0
# ...

# %%
countries_clean_df = countries_df.rename(index = str, columns={"name": "Nation"})
countries_clean_df.head()
# Out:
#   country   latitude  longitude                Nation
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
countries_clean_df.to_csv(r'LatLong.csv', index = False)

# %%
climate_clean_df.to_csv(r'climate_data.csv', index = False)
