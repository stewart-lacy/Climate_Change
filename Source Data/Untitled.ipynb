# %%
import pandas as pd

# %%
load_nation_data = pd.read_csv("nation.1751_2014.csv")
clean_nation_data=load_nation_data.dropna()

# %%
clean_nation_data
# Out:
#             Nation  Year  \
# 0      AFGHANISTAN  1949
# 1      AFGHANISTAN  1950
# 2      AFGHANISTAN  1951
# 3      AFGHANISTAN  1952
# 4      AFGHANISTAN  1953
# ...            ...   ...
# 17227     ZIMBABWE  2010
# 17228     ZIMBABWE  2011
# 17229     ZIMBABWE  2012
# 17230     ZIMBABWE  2013
# 17231     ZIMBABWE  2014
#
#        Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 0                                                      4
# 1                                                     23
# 2                                                     25
# 3                                                     25
# 4                                                     29
# ...                                                  ...
# 17227                                               2121
# 17228                                               2608
# 17229                                               2125
# ...

# %%
countries_geo = pd.read_csv("countries_geo.csv")
countries_geo
# Out:
#     country   latitude  longitude                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]
