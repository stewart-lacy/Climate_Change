# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
username = "postgres"
password = 'basketball' #Insert your password
database = "Climate_Change_Project"
rds_connection_string = f'{username}:{password}@localhost:5432/{database}'
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
csv_file = "combined_csv.csv"
csv_df = pd.read_csv(csv_file)
csv_df
# Out:
#      country_std  year_1995  year_1996  year_1997  year_1998  year_1999  \
# 0    Afghanistan       0.02       0.02       0.01       0.01       0.01
# 1        Albania       0.18       0.18       0.14       0.16       0.26
# 2        Algeria       0.92       0.92       0.81       0.98       0.83
# 3        Andorra       1.79       1.90       1.96       2.09       2.19
# 4         Angola       0.25       0.23       0.16       0.15       0.18
# ..           ...        ...        ...        ...        ...        ...
# 178    Venezuela       1.65       1.49       1.59       1.95       1.98
# 179      Vietnam       0.11       0.13       0.16       0.17       0.17
# 180        Yemen       0.19       0.18       0.22       0.20       0.22
# 181       Zambia       0.07       0.06       0.07       0.07       0.05
# 182     Zimbabwe       0.35       0.34       0.33       0.32       0.35
#
#      year_2000  year_2001  year_2002  year_2003  ...  year_2008  year_2009  \
# ...

# %%
csv_df.to_sql(name = 'Climate_data', con = engine, if_exists = 'replace', index =False)

# %%
engine.table_names()
# Out:
# ['climate_data', 'Climate_Change_Project', 'Climate_data']

# %%
pd.read_sql_query('select * from climate_data',con=engine)
# Out:
# Empty DataFrame
# Columns: [country_std, year_1995, year_1996, year_1997, year_1998, year_1999, year_2000, year_2001, year_2002, year_2003, year_2004, year_2005, year_2006, year_2007, year_2008, year_2009, year_2010, year_2011, year_2012, year_2013, year_2014, country, latitude, longitude]
# Index: []
#
# [0 rows x 24 columns]
